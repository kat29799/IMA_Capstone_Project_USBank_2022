# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# # **1. Load and Clean Data**

# %%
#read dataset
df = pd.read_csv('../data/RecursionCohortData_27339_2001-01-01_2022-07-01_1657909974300.csv')

# %% [markdown]
# Now let us look at what the information of our dataset. Chris said that he used -999 for N/A value. There are nan values in both 'Orig LTV Desciption' and  'Credit Score Description' columns, but we don't need to replace those values becuase they are description.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2501 entries, 0 to 2500
# Data columns (total 17 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Bank Servicer(Y/N)                    2496 non-null   object
#  1   Orig LTV                              2501 non-null   int64
#  2   Orig LTV Description                  2501 non-null   object
#  3   Credit Score                          2501 non-null   int64
#  4   Credit Score Description              2501 non-null   object
#  5   Factor Date                           2501 non-null   object
#  6   Current Remaining Principal Balance   2501 non-null   float64
#  7   Item Count                            2501 non-null   int64
#  8   Weighted Average Gross Coupon         2501 non-null   float64
#  9   Weighted Average Maturity             2501 non-null   float64
#  10  Weighted Average Loan Age             2501 non-null   float64
#  11  Weighted Average Original Loan Size   2501 non-null   float64
#  12  Weighted Average Loan Size            2501 non-null   float64
#  13  Original Loan Amount                  2501 non-null   float64
#  14  CPR 1M                                2472 non-null   float64
#  15  CDR 1M                                384 non-null    float64
#  16  CCR 1M (Curtailment)                  2472 non-null   float64
# dtypes: float64(10), int64(3), object(4)
# memory usage: 332.3+ KB

# %%
df.columns
# Out:
# Index(['Bank Servicer(Y/N)', 'Orig LTV', 'Orig LTV Description',
#        'Credit Score', 'Credit Score Description', 'Factor Date',
#        'Current Remaining Principal Balance ', 'Item Count ',
#        'Weighted Average Gross Coupon ', 'Weighted Average Maturity ',
#        'Weighted Average Loan Age ', 'Weighted Average Original Loan Size ',
#        'Weighted Average Loan Size ', 'Original Loan Amount ', 'CPR 1M ',
#        'CDR 1M ', 'CCR 1M (Curtailment) '],
#       dtype='object')

# %%
df.head()
# Out:
#   Bank Servicer(Y/N)  Orig LTV Orig LTV Description  Credit Score  \
# 0                  N      -999                 N.A.          -999
# 1                  N      -999                 N.A.           680
# 2                  N      -999                 N.A.           750
# 3                  N      -999                 N.A.         29999
# 4                  N        80                 <=80          -999
#
#   Credit Score Description Factor Date  Current Remaining Principal Balance   \
# 0                     N.A.    7/1/2022                          2.177325e+10
# 1                    <=680    7/1/2022                          7.269392e+07
# 2           >680 and <=750    7/1/2022                          7.726510e+07
# 3                     >750    7/1/2022                          3.129921e+07
# 4                     N.A.    7/1/2022                          5.170670e+08
#
#    Item Count   Weighted Average Gross Coupon   Weighted Average Maturity   \
# 0       147332                        4.406054                  338.912020
# 1          636                        3.630607                  329.901856
# 2          620                        3.434372                  331.560343
# 3          245                        3.346467                  327.675719
# 4         3850                        4.058299                  260.348302
#
#    Weighted Average Loan Age   Weighted Average Original Loan Size   \
# 0                   91.007777                           236477.4371
# 1                   28.439182                           145947.9172
# 2                   23.936819                           162110.3959
# 3                   25.915448                           174182.9081
# 4                   51.254905                           268204.3842
#
#    Weighted Average Loan Size   Original Loan Amount   CPR 1M   CDR 1M   \
# 0                  202495.7865           2.630744e+10      NaN      NaN
# 1                  139133.1410           7.708400e+07      NaN      NaN
# 2                  154341.8838           8.115500e+07      NaN      NaN
# 3                  164687.4867           3.394000e+07      NaN      NaN
# 4                  240469.7537           6.569670e+08      NaN      NaN
#
#    CCR 1M (Curtailment)
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN

# %%
#replace nan values by 0, and replace the initial dataframe
df.fillna(0,inplace = True)

# %% [markdown]
# # **2. Data Visualization**

# %%
#sort data by 'Factor Date' from old to new
df.sort_values(by=['Factor Date'], ascending=True, inplace=True)
df['Factor Date']=pd.to_datetime(df['Factor Date'])
df = df[df['Factor Date'] < '2022-7-1']

# %% [markdown]
# Now, let us plot some graphs.

# %%
sns.set(rc = {'figure.figsize':(20,10)})
sns.lineplot(data=df, x='Factor Date', y= 'CPR 1M ', hue ='Credit Score Description')
# Out:
# <AxesSubplot:xlabel='Factor Date', ylabel='CPR 1M '>

# %%
sns.set(rc = {'figure.figsize':(20,10)})
sns.lineplot(data=df, x='Factor Date', y= 'CPR 1M ', hue ='Orig LTV Description')
# Out:
# <AxesSubplot:xlabel='Factor Date', ylabel='CPR 1M '>

# %% [markdown]
# It seems like that we have too many data in 'Factor Date' and we can not see every single date very clearly. Let us look a specific period. I am interested in covid period, so I plot graph from 2020-2022.

# %%
#define dataframe after covid time
df_covid = df[df['Factor Date']>'2019-12-1']

# %%
df_covid.head()
# Out:
#     Bank Servicer(Y/N)  Orig LTV Orig LTV Description  Credit Score  \
# 727                  N      -999                 N.A.           750
# 735                  N     29999                  >80           750
# 728                  N      -999                 N.A.         29999
# 729                  N        80                 <=80          -999
# 730                  N        80                 <=80           680
#
#     Credit Score Description Factor Date  \
# 727           >680 and <=750  2020-01-01
# 735           >680 and <=750  2020-01-01
# 728                     >750  2020-01-01
# 729                     N.A.  2020-01-01
# 730                    <=680  2020-01-01
#
#      Current Remaining Principal Balance   Item Count   \
# 727                          9.050025e+07          674
# 735                          2.797380e+11      1302677
# 728                          1.903624e+07          169
# 729                          6.538415e+08         4673
# 730                          1.393960e+11       822997
#
#      Weighted Average Gross Coupon   Weighted Average Maturity   \
# 727                        4.415835                  357.897893
# 735                        4.351093                  317.636102
# 728                        4.285623                  317.461956
# 729                        4.527041                  292.307395
# 730                        4.550802                  292.705561
#
#      Weighted Average Loan Age   Weighted Average Original Loan Size   \
# 727                   62.742825                           176130.4065
# 735                   31.058750                           286650.2389
# 728                   56.052210                           171346.2301
# 729                   53.053017                           246066.8046
# 730                   37.996532                           257684.0772
#
#      Weighted Average Loan Size   Original Loan Amount     CPR 1M   CDR 1M   \
# 727                  159539.4468           9.999800e+07   9.488754      0.0
# 735                  271461.7129           2.996010e+11  16.726801      0.0
# 728                  150681.5697           2.230100e+07   5.043276      0.0
# 729                  220007.9261           7.883150e+08  22.320664      0.0
# 730                  239115.6967           1.543120e+11  18.509062      0.0
#
#      CCR 1M (Curtailment)
# 727               0.212392
# 735               0.416761
# 728               2.404894
# 729               1.650345
# 730               0.457410

# %% [markdown]
# Now, let us plot graph for this specific period of time.

# %%
sns.set(rc = {'figure.figsize':(20,10)})
sns.lineplot(data=df_covid, x='Factor Date', y= 'CPR 1M ', hue ='Credit Score Description')
# Out:
# <AxesSubplot:xlabel='Factor Date', ylabel='CPR 1M '>

# %%
sns.set(rc = {'figure.figsize':(20,10)})
sns.lineplot(data=df_covid, x='Factor Date', y= 'CPR 1M ', hue ='Orig LTV Description')
# Out:
# <AxesSubplot:xlabel='Factor Date', ylabel='CPR 1M '>

# %% [markdown]
# You guys can play around by changing 'hue' to other categorial features

# %%
sns.boxplot(x="Credit Score Description", y="CPR 1M ", data=df)
# Out:
# <AxesSubplot:xlabel='Credit Score Description', ylabel='CPR 1M '>

# %%
sns.boxplot(x='Orig LTV Description', y="CPR 1M ", data=df)
# Out:
# <AxesSubplot:xlabel='Orig LTV Description', ylabel='CPR 1M '>

# %% [markdown]
# # **3. Statistical Analysis**

# %% [markdown]
# Now, I  make a correlation matrix plot to see their correlations.

# %%
# import library
import matplotlib.pyplot as plt

# %%
# Identiy numerical features
num_features = pd.Index(['Current Remaining Principal Balance ', 'Item Count ', 
 'Weighted Average Gross Coupon ', 'Weighted Average Maturity ','Weighted Average Loan Age ', 
 'Weighted Average Original Loan Size ','Weighted Average Loan Size ', 'Original Loan Amount ', 'CPR 1M '])

# %%
# Define a dataframe that only contains numerical features
num_df = df[num_features]

# %%
# Correlation matrix
cormat = num_df.corr()
round(cormat, 2)
# Out:
#                                       Current Remaining Principal Balance   \
# Current Remaining Principal Balance                                   1.00
# Item Count                                                            0.99
# Weighted Average Gross Coupon                                        -0.38
# Weighted Average Maturity                                            -0.21
# Weighted Average Loan Age                                            -0.16
# Weighted Average Original Loan Size                                   0.56
# Weighted Average Loan Size                                            0.55
# Original Loan Amount                                                  1.00
# CPR 1M                                                                0.23
#
#                                       Item Count   \
# Current Remaining Principal Balance          0.99
# Item Count                                   1.00
# Weighted Average Gross Coupon               -0.36
# Weighted Average Maturity                   -0.24
# Weighted Average Loan Age                   -0.15
# Weighted Average Original Loan Size          0.56
# Weighted Average Loan Size                   0.54
# Original Loan Amount                         0.99
# CPR 1M                                       0.23
#
#                                       Weighted Average Gross Coupon   \
# Current Remaining Principal Balance                            -0.38
# Item Count                                                     -0.36
# Weighted Average Gross Coupon                                   1.00
# Weighted Average Maturity                                      -0.47
# Weighted Average Loan Age                                       0.73
# Weighted Average Original Loan Size                            -0.28
# Weighted Average Loan Size                                     -0.34
# Original Loan Amount                                           -0.38
# CPR 1M                                                          0.04
#
#                                       Weighted Average Maturity   \
# Current Remaining Principal Balance                        -0.21
# Item Count                                                 -0.24
# Weighted Average Gross Coupon                              -0.47
# Weighted Average Maturity                                   1.00
# Weighted Average Loan Age                                  -0.45
# Weighted Average Original Loan Size                        -0.13
# Weighted Average Loan Size                                 -0.06
# Original Loan Amount                                       -0.22
# CPR 1M                                                     -0.20
#
#                                       Weighted Average Loan Age   \
# Current Remaining Principal Balance                        -0.16
# Item Count                                                 -0.15
# Weighted Average Gross Coupon                               0.73
# Weighted Average Maturity                                  -0.45
# Weighted Average Loan Age                                   1.00
# Weighted Average Original Loan Size                        -0.23
# Weighted Average Loan Size                                 -0.35
# Original Loan Amount                                       -0.15
# CPR 1M                                                      0.22
#
#                                       Weighted Average Original Loan Size   \
# Current Remaining Principal Balance                                   0.56
# Item Count                                                            0.56
# Weighted Average Gross Coupon                                        -0.28
# Weighted Average Maturity                                            -0.13
# Weighted Average Loan Age                                            -0.23
# Weighted Average Original Loan Size                                   1.00
# Weighted Average Loan Size                                            0.99
# Original Loan Amount                                                  0.55
# CPR 1M                                                                0.39
#
#                                       Weighted Average Loan Size   \
# Current Remaining Principal Balance                          0.55
# Item Count                                                   0.54
# Weighted Average Gross Coupon                               -0.34
# Weighted Average Maturity                                   -0.06
# Weighted Average Loan Age                                   -0.35
# Weighted Average Original Loan Size                          0.99
# Weighted Average Loan Size                                   1.00
# Original Loan Amount                                         0.54
# CPR 1M                                                       0.34
#
#                                       Original Loan Amount   CPR 1M
# Current Remaining Principal Balance                    1.00     0.23
# Item Count                                             0.99     0.23
# Weighted Average Gross Coupon                         -0.38     0.04
# Weighted Average Maturity                             -0.22    -0.20
# Weighted Average Loan Age                             -0.15     0.22
# Weighted Average Original Loan Size                    0.55     0.39
# Weighted Average Loan Size                             0.54     0.34
# Original Loan Amount                                   1.00     0.23
# CPR 1M                                                 0.23     1.00

# %% [markdown]
# I inlcude the feature 'Itemm Count' just because it is a numerical feature. We can just ignore now. Let us look at the last column or last row. We observe that 'Weighted Average Maturity' has negative correlation with 'CPR 1M'. The 'Weighted Average Gross Coupon' has almost zero correlation. Two features that has relatively high correlation are 'Weighted Average Original Loan Size' and 'Weighted Average Loan Size'. The correlation between 'Weighted Average Original Loan Size' and 'Weighted Average Loan Size' is 0.99, which is very close to 1. We can ignore one of them when we build up a model.

# %% [markdown]
# Now, let us drop 'Item Count' and 'Weighted Average Original Loan Size' to plot a clear graph.

# %%
df_new = num_df.drop(['Item Count ', 'Weighted Average Original Loan Size '], axis=1)
cormat_new = df_new.corr()
sns.heatmap(cormat_new)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # **Time Series Plots: Bank vs. Non-Bank**

# %%
df_bank = df[df['Bank Servicer(Y/N)'] == 'Y']
df_nonbank = df[df['Bank Servicer(Y/N)'] == 'N']

# %%
df_bank.columns
# Out:
# Index(['Bank Servicer(Y/N)', 'Orig LTV', 'Orig LTV Description',
#        'Credit Score', 'Credit Score Description', 'Factor Date',
#        'Current Remaining Principal Balance ', 'Item Count ',
#        'Weighted Average Gross Coupon ', 'Weighted Average Maturity ',
#        'Weighted Average Loan Age ', 'Weighted Average Original Loan Size ',
#        'Weighted Average Loan Size ', 'Original Loan Amount ', 'CPR 1M ',
#        'CDR 1M ', 'CCR 1M (Curtailment) '],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

sns.lineplot(x = "Factor Date", y = "CPR 1M ", data = df_bank)
sns.lineplot(x = "Factor Date", y = "CPR 1M ", data = df_nonbank)
plt.legend(labels = ["Bank Issued", "Non-Bank Issued"])

# %% [markdown]
# # **Define and Train Model**

# %% [markdown]
# To be continued....
