# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading the datasets
HPI = pd.read_csv("USSTHPI.csv") # Quarterly HPI data
HPI_PO = pd.read_excel("HPI_PO_summary.xls") # HPI Purchase Only data
EHS = pd.read_excel("Existing Home Sales.xlsx") # Existing Home Sales data, Chris supplied
HouseStock = pd.read_excel("HousingStockWorksheet.xlsx") # Housing Stock data, Chris supplied

# %%
HPI.DATE = pd.to_datetime(HPI.DATE)
HPI.head(10)
# Out:
#         DATE  USSTHPI
# 0 1975-01-01    60.02
# 1 1975-04-01    60.96
# 2 1975-07-01    61.16
# 3 1975-10-01    62.22
# 4 1976-01-01    62.86
# 5 1976-04-01    65.45
# 6 1976-07-01    66.53
# 7 1976-10-01    67.26
# 8 1977-01-01    69.49
# 9 1977-04-01    72.72

# %%
# Juct cleaning the HPI_PO data a little bit
new_header = HPI_PO.iloc[0]
HPI_PO = HPI_PO[1:]
HPI_PO.columns = new_header

# %%
# Creating a column to calculate and store YoY % Change in HPI
HPI["YoY"] = 0
for i in range(4,HPI.shape[0]):
    HPI.YoY.iloc[i] = (HPI.USSTHPI[i]/HPI.USSTHPI[i-4])-1
HPI.head(10)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#         DATE  USSTHPI       YoY
# 0 1975-01-01    60.02  0.000000
# 1 1975-04-01    60.96  0.000000
# 2 1975-07-01    61.16  0.000000
# 3 1975-10-01    62.22  0.000000
# 4 1976-01-01    62.86  0.047318
# 5 1976-04-01    65.45  0.073655
# 6 1976-07-01    66.53  0.087802
# 7 1976-10-01    67.26  0.081003
# 8 1977-01-01    69.49  0.105472
# 9 1977-04-01    72.72  0.111077

# %%
plt.figure(figsize=(18,12))
plt.plot(HPI.DATE, HPI.YoY)
plt.title("YoY% Change of HPI", size = 22);

# %%
plt.figure(figsize=(18,12))
plt.plot(HPI.DATE, HPI.USSTHPI)
plt.title("Plot of HPI", size = 22)
# Out:
# Text(0.5, 1.0, 'Plot of HPI')
