# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
reasons_left = pd.read_excel('../data/hst_mig_a_5.xlsx')
migration_total = pd.read_excel('../data/hst_mig_a_1.xlsx', skiprows = 6)
migration_regions = pd.read_excel('../data/hst_mig_a_2.xlsx', skiprows=3)

# %%
list[migration_total.columns]
# Out:
# list[Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', '...\nTotal\n', '...\nSame state\n',
#        '...\nDifferent state\n', 'Unnamed: 9'],
#       dtype='object')]

# %%
migration_regions.head()
# Out:
#   Mobility Period and Type of Migration  Inmigrants  Outmigrants  \
# 0                             2020-2021         NaN          NaN
# 1                          \t.Northeast       221.0        448.0
# 2                            \t.Midwest       397.0        530.0
# 3                              \t.South      1027.0        774.0
# 4                               \t.West       655.0        547.0
#
#    Net internal migration  Movers from abroad  \
# 0                     NaN                 NaN
# 1                  -227.0                81.0
# 2                  -134.0                63.0
# 3                   253.0               323.0
# 4                   108.0               144.0
#
#    Net migration (including abroad)
# 0                               NaN
# 1                            -146.0
# 2                             -71.0
# 3                             576.0
# 4                             252.0

# %%
Northeast = migration_regions[migration_regions["Mobility Period and Type of Migration"] == "\t.Northeast"]
Midwest = migration_regions[migration_regions["Mobility Period and Type of Migration"] == "\t.Midwest"]
South = migration_regions[migration_regions["Mobility Period and Type of Migration"] == "\t.South"]
West = migration_regions[migration_regions["Mobility Period and Type of Migration"] == "\t.West"]

# %%
Northeast.head()
# Out:
#    Mobility Period and Type of Migration  Inmigrants  Outmigrants  \
# 1                           \t.Northeast       221.0        448.0
# 6                           \t.Northeast       284.0        449.0
# 11                          \t.Northeast       327.0        565.0
# 16                          \t.Northeast       243.0        595.0
# 21                          \t.Northeast       405.0        606.0
#
#     Net internal migration  Movers from abroad  \
# 1                   -227.0                81.0
# 6                   -165.0               196.0
# 11                  -238.0               205.0
# 16                  -352.0               229.0
# 21                  -200.0               223.0
#
#     Net migration (including abroad)
# 1                             -146.0
# 6                               31.0
# 11                             -34.0
# 16                            -124.0
# 21                              23.0

# %%
sns.lineplot(data = Northeast["Net migration (including abroad)"])
sns.lineplot(data = Midwest["Net migration (including abroad)"])
sns.lineplot(data = South["Net migration (including abroad)"])
sns.lineplot(data = West["Net migration (including abroad)"])
plt.legend(labels=["Northeast","Midwest", "South", "West"])

# %%
sns.lineplot(data = migration_total["...\nTotal\n"].iloc[0:85])
# Out:
# <AxesSubplot:ylabel='...\nTotal\n'>
